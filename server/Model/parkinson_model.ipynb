# %% [markdown]
# #### Import required libraries:

# %%
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import load_img, img_to_array , to_categorical
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten,MaxPool2D,Conv2D
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %% [markdown]
# #### Initializing data folders

# %%
dir_sp_train = "drawings/spiral/training"
dir_sp_test = "drawings/spiral/testing"
dir_wa_train = "drawings/wave/training"
dir_wa_test = "drawings/wave/testing"

# %%
Name = []
for file in os.listdir(dir_sp_train):
    Name+=[file]
print (Name)
# Out:
# ['healthy', 'parkinson']

# %%
# Mapping image to tag
N = []
for i in range(len(Name)):
    N+=[i]

reverse_mapping = dict(zip(N,Name))

#function for getting 0(healthy) and 1(parkinson)
def mapper(value):
    return reverse_mapping[value]

# %%
# Creating training dataset for spiral images 
dataset_sp = []
count = 0
for file in os.listdir(dir_sp_train):
    path = os.path.join(dir_sp_train,file)
    for im in os.listdir(path):
        image = load_img(os.path.join(path,im),grayscale=False,color_mode = 'rgb' ,target_size = (100,100))
        image = img_to_array(image)
        image = image/255.0
        dataset_sp.append([image,count])
    count+=1

# Creating testing dataset for spiral images 
testset_sp = []
count = 0
for file in os.listdir(dir_sp_test):
    path = os.path.join(dir_sp_test,file)
    for im in os.listdir(path):
        image = load_img(os.path.join(path,im),grayscale=False,color_mode = 'rgb' ,target_size = (100,100))
        image = img_to_array(image)
        image = image/255.0
        testset_sp.append([image,count])
    count+=1

# %%
# Creating training dataset for wave images 
dataset_wa = []
count = 0
for file in os.listdir(dir_wa_train):
    path = os.path.join(dir_wa_train,file)
    for im in os.listdir(path):
        image = load_img(os.path.join(path,im),grayscale=False,color_mode = 'rgb' ,target_size = (100,100))
        image = img_to_array(image)
        image = image/255.0
        dataset_wa.append([image,count])
    count+=1

# Creating testing dataset for wave images 
testset_wa = []
count = 0
for file in os.listdir(dir_wa_test):
    path = os.path.join(dir_wa_test,file)
    for im in os.listdir(path):
        image = load_img(os.path.join(path,im),grayscale=False,color_mode = 'rgb' ,target_size = (100,100))
        image = img_to_array(image)
        image = image/255.0
        testset_wa.append([image,count])
    count+=1

# %%
# Spliting image and it's label
data_sp,lables_sp0 = zip(*dataset_sp)
test_sp,tlables_sp0 = zip(*testset_sp)

data_wa,lables_wa0 = zip(*dataset_wa)
test_wa,tlables_wa0 = zip(*testset_wa)

# %%
# Converting labels to numerical(binary) for spiral images
lables_sp1 = to_categorical(lables_sp0)
data_sp = np.array(data_sp)
lables_sp = np.array(lables_sp1)

tlables_sp1 = to_categorical(tlables_sp0)
test_sp = np.array(test_sp)
tlables_sp = np.array(tlables_sp1)

# %%
# Converting labels to numerical(binary) data for wave images
lables_wa1 = to_categorical(lables_wa0)
data_wa = np.array(data_wa)
lables_wa = np.array(lables_wa1)

tlables_wa1 = to_categorical(tlables_wa0)
test_wa = np.array(test_wa)
tlables_wa = np.array(tlables_wa1)

# %%
# Spiliting data into train and validation data
trainx_sp,validx_sp,trainy_sp,validy_sp = train_test_split(data_sp,lables_sp,test_size=0.2,random_state=44)
trainx_wa,validx_wa,trainy_wa,validy_wa = train_test_split(data_wa,lables_wa,test_size=0.2,random_state=44)

# %%
# Viewing shape of data of spiral
print(trainx_sp.shape)
print(validx_sp.shape)
print(trainy_sp.shape)
print(validy_sp.shape)
# Out:
# (57, 100, 100, 3)
# (15, 100, 100, 3)
# (57, 2)
# (15, 2)

# %%
# Viewing shape of data of wave
print(trainx_wa.shape)
print(validx_wa.shape)
print(trainy_wa.shape)
print(validy_wa.shape)
# Out:
# (57, 100, 100, 3)
# (15, 100, 100, 3)
# (57, 2)
# (15, 2)

# %% [markdown]
# ### CNN Model:

# %%
# CNN Architecture:
# model = Sequential()

# model.add(Conv2D(filters=32, kernel_size = (5,5),activation='relu',input_shape=(100,100,3)))
# model.add(MaxPool2D(pool_size=(2,2)))

# model.add(Conv2D(filters=64, kernel_size = (5,5),activation='relu'))
# model.add(MaxPool2D(pool_size=(2,2)))

# model.add(Flatten())
# model.add(Dense(units=64,activation="relu"))
# model.add(Dense(units=2,activation="softmax"))

# model.compile(loss='categorical_crossentropy', optimizer = Adam(learning_rate=0.001), metrics=['accuracy'])

# print("Model Summary")
# model.summary()

# %%
# training spiral and wave model:
# epoch = 100
# batch_size = 32

# print("Start Training",'\n')
# hist_0 = model.fit(trainx_sp,trainy_sp,batch_size=batch_size,epochs=epoch,validation_data=(validx_sp, validy_sp))
# hist_1 = model.fit(trainx_wa,trainy_wa,batch_size=batch_size,epochs=epoch,validation_data=(validx_wa, validy_wa))
# print("Training end",'\n')

# model.save("CNN_Model.h5")

# %% [markdown]
# ### Visualizing accuracy and loss of training and validation dataset:

# %%
# for Spiral dataset:
# figure = plt.figure(figsize=(10,10))
# plt.plot(hist_0.history['accuracy'],label= 'Train Accuracy')
# plt.plot(hist_0.history['val_accuracy'],label= 'Test Accuracy')
# plt.title("Model Accuracy for Spiral")
# plt.xlabel("Epochs")
# plt.ylabel("Accuracy")
# plt.legend(loc='upper left')
# plt.show()

# figure2 = plt.figure(figsize=(10,10))
# plt.plot(hist_0.history['loss'],label= 'Train loss')
# plt.plot(hist_0.history['val_loss'],label= 'Test loss')
# plt.title("Model loss for Spiral")
# plt.xlabel("Epochs")
# plt.ylabel("Loss")
# plt.legend(loc='upper left')
# plt.show()

# %%
# for Wave dataset:
# figure = plt.figure(figsize=(10,10))
# plt.plot(hist_1.history['accuracy'],label= 'Train Accuracy')
# plt.plot(hist_1.history['val_accuracy'],label= 'Test Accuracy')
# plt.title("Model Accuracy for Wave")
# plt.xlabel("Epochs")
# plt.ylabel("Accuracy")
# plt.legend(loc='upper left')
# plt.show()

# figure2 = plt.figure(figsize=(10,10))
# plt.plot(hist_1.history['loss'],label= 'Train loss')
# plt.plot(hist_1.history['val_loss'],label= 'Test loss')
# plt.title("Model loss for Wave")
# plt.xlabel("Epochs")
# plt.ylabel("Loss")
# plt.legend(loc='upper left')
# plt.show()

# %% [markdown]
# ### Conclusion of CNN model:
# Overfitting occurs because the model cannot generalize and fits too closely to the training dataset. Overfitting happens due to several reasons, here, The training data size is too small and does not contain enough data samples to accurately represent all possible input data values.

# %% [markdown]
# ### We are trying to optimizing the model:
# Using image augmentation and transfer learning (pretrained model), also if required we will use ensembles technique

# %%
datagen = ImageDataGenerator(horizontal_flip=True,vertical_flip=True,rotation_range=20,zoom_range=0.2,
width_shift_range=0.2,height_shift_range=0.2,shear_range=0.1,fill_mode="nearest")

# %%
# pretrained_model3 = tf.keras.applications.ResNet152(input_shape=(100,100,3),include_top=False,weights='imagenet',pooling='avg')
# pretrained_model3.trainable = False

# pretrained_model4 = tf.keras.applications.ResNet152(input_shape=(100,100,3),include_top=False,weights='imagenet',pooling='avg')
# pretrained_model4.trainable = False

# %%
# VGG16 model:
pretrained_model3 = tf.keras.applications.VGG16(input_shape=(100,100,3),include_top=False,weights='imagenet',pooling='avg')
pretrained_model3.trainable = False

pretrained_model4 = tf.keras.applications.VGG16(input_shape=(100,100,3),include_top=False,weights='imagenet',pooling='avg')
pretrained_model4.trainable = False

# %%
# intializing last layer and output layer:
inputs3 = pretrained_model3.input
x3 = tf.keras.layers.Dense(128,activation='relu')(pretrained_model3.output)
outputs3 = tf.keras.layers.Dense(2,activation='softmax')(x3)
model3 = tf.keras.Model(inputs=inputs3, outputs=outputs3)

inputs4 = pretrained_model4.input
x4 = tf.keras.layers.Dense(128,activation='relu')(pretrained_model4.output)
outputs4 = tf.keras.layers.Dense(2,activation='softmax')(x4)
model4 = tf.keras.Model(inputs=inputs4, outputs=outputs4)

model3.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model4.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
# fitting and predictions on spiral and wave dataset:
sp_3=model3.fit(datagen.flow(trainx_sp,trainy_sp,batch_size=32),validation_data=(validx_sp, validy_sp),epochs=100)
wa_4=model4.fit(datagen.flow(trainx_wa,trainy_wa,batch_size=32),validation_data=(validx_wa, validy_wa),epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.9796 - accuracy: 0.4737 - val_loss: 0.6912 - val_accuracy: 0.6000
# Epoch 2/100
# 2/2 [==============================] - 1s 732ms/step - loss: 0.7266 - accuracy: 0.3860 - val_loss: 0.8418 - val_accuracy: 0.4000
# Epoch 3/100
# 2/2 [==============================] - 1s 916ms/step - loss: 0.7615 - accuracy: 0.5263 - val_loss: 0.9005 - val_accuracy: 0.4000
# Epoch 4/100
# 2/2 [==============================] - 2s 835ms/step - loss: 0.7275 - accuracy: 0.5263 - val_loss: 0.7695 - val_accuracy: 0.4000
# Epoch 5/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.6653 - accuracy: 0.6140 - val_loss: 0.6223 - val_accuracy: 0.6000
# Epoch 6/100
# 2/2 [==============================] - 1s 887ms/step - loss: 0.6421 - accuracy: 0.6316 - val_loss: 0.5562 - val_accuracy: 0.9333
# Epoch 7/100
# 2/2 [==============================] - 1s 945ms/step - loss: 0.6654 - accuracy: 0.5263 - val_loss: 0.5308 - val_accuracy: 0.9333
# Epoch 8/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.6193 - accuracy: 0.6316 - val_loss: 0.5353 - val_accuracy: 0.8667
# Epoch 9/100
# 2/2 [==============================] - 1s 832ms/step - loss: 0.6022 - accuracy: 0.6842 - val_loss: 0.5774 - val_accuracy: 0.6000
# Epoch 10/100
# 2/2 [==============================] - 2s 771ms/step - loss: 0.5727 - accuracy: 0.7719 - val_loss: 0.6358 - val_accuracy: 0.6000
# Epoch 11/100
# 2/2 [==============================] - 2s 803ms/step - loss: 0.5899 - accuracy: 0.7018 - val_loss: 0.6621 - val_accuracy: 0.6000
# Epoch 12/100
# 2/2 [==============================] - 2s 987ms/step - loss: 0.5581 - accuracy: 0.7018 - val_loss: 0.6493 - val_accuracy: 0.6000
# Epoch 13/100
# 2/2 [==============================] - 1s 829ms/step - loss: 0.5576 - accuracy: 0.7544 - val_loss: 0.5842 - val_accuracy: 0.6000
# Epoch 14/100
# 2/2 [==============================] - 1s 892ms/step - loss: 0.5676 - accuracy: 0.7368 - val_loss: 0.4942 - val_accuracy: 0.8000
# Epoch 15/100
# 2/2 [==============================] - 1s 927ms/step - loss: 0.5398 - accuracy: 0.7544 - val_loss: 0.4536 - val_accuracy: 0.8000
# Epoch 16/100
# 2/2 [==============================] - 1s 887ms/step - loss: 0.5582 - accuracy: 0.7719 - val_loss: 0.4372 - val_accuracy: 0.8000
# Epoch 17/100
# 2/2 [==============================] - 1s 748ms/step - loss: 0.5337 - accuracy: 0.7895 - val_loss: 0.4640 - val_accuracy: 0.8000
# Epoch 18/100
# 2/2 [==============================] - 1s 763ms/step - loss: 0.5246 - accuracy: 0.8070 - val_loss: 0.5096 - val_accuracy: 0.6667
# Epoch 19/100
# 2/2 [==============================] - 1s 942ms/step - loss: 0.5448 - accuracy: 0.7895 - val_loss: 0.5411 - val_accuracy: 0.6000
# Epoch 20/100
# 2/2 [==============================] - 1s 678ms/step - loss: 0.5588 - accuracy: 0.7544 - val_loss: 0.5389 - val_accuracy: 0.6000
# Epoch 21/100
# 2/2 [==============================] - 1s 692ms/step - loss: 0.4591 - accuracy: 0.8596 - val_loss: 0.5009 - val_accuracy: 0.7333
# Epoch 22/100
# 2/2 [==============================] - 1s 808ms/step - loss: 0.5102 - accuracy: 0.8070 - val_loss: 0.4692 - val_accuracy: 0.8000
# Epoch 23/100
# 2/2 [==============================] - 1s 754ms/step - loss: 0.4923 - accuracy: 0.8070 - val_loss: 0.4610 - val_accuracy: 0.8000
# Epoch 24/100
# 2/2 [==============================] - 1s 643ms/step - loss: 0.5029 - accuracy: 0.7895 - val_loss: 0.4460 - val_accuracy: 0.8000
# Epoch 25/100
# 2/2 [==============================] - 1s 750ms/step - loss: 0.4806 - accuracy: 0.8070 - val_loss: 0.4692 - val_accuracy: 0.8000
# Epoch 26/100
# 2/2 [==============================] - 1s 747ms/step - loss: 0.4745 - accuracy: 0.8070 - val_loss: 0.5045 - val_accuracy: 0.6667
# Epoch 27/100
# 2/2 [==============================] - 1s 637ms/step - loss: 0.5041 - accuracy: 0.7895 - val_loss: 0.4880 - val_accuracy: 0.7333
# Epoch 28/100
# 2/2 [==============================] - 1s 628ms/step - loss: 0.4906 - accuracy: 0.7544 - val_loss: 0.4484 - val_accuracy: 0.8000
# Epoch 29/100
# 2/2 [==============================] - 1s 742ms/step - loss: 0.4597 - accuracy: 0.7544 - val_loss: 0.4613 - val_accuracy: 0.8000
# Epoch 30/100
# 2/2 [==============================] - 1s 742ms/step - loss: 0.4418 - accuracy: 0.8246 - val_loss: 0.4585 - val_accuracy: 0.8000
# Epoch 31/100
# 2/2 [==============================] - 1s 623ms/step - loss: 0.4621 - accuracy: 0.8070 - val_loss: 0.4408 - val_accuracy: 0.8000
# Epoch 32/100
# 2/2 [==============================] - 1s 743ms/step - loss: 0.5071 - accuracy: 0.7544 - val_loss: 0.4482 - val_accuracy: 0.8000
# Epoch 33/100
# 2/2 [==============================] - 1s 728ms/step - loss: 0.4544 - accuracy: 0.7719 - val_loss: 0.4459 - val_accuracy: 0.8000
# Epoch 34/100
# 2/2 [==============================] - 1s 625ms/step - loss: 0.4281 - accuracy: 0.8421 - val_loss: 0.4658 - val_accuracy: 0.8000
# Epoch 35/100
# 2/2 [==============================] - 1s 652ms/step - loss: 0.4293 - accuracy: 0.8421 - val_loss: 0.4782 - val_accuracy: 0.8000
# Epoch 36/100
# 2/2 [==============================] - 1s 622ms/step - loss: 0.4426 - accuracy: 0.8070 - val_loss: 0.4697 - val_accuracy: 0.8000
# Epoch 37/100
# 2/2 [==============================] - 1s 745ms/step - loss: 0.4755 - accuracy: 0.7544 - val_loss: 0.4788 - val_accuracy: 0.8000
# Epoch 38/100
# 2/2 [==============================] - 1s 908ms/step - loss: 0.4220 - accuracy: 0.8596 - val_loss: 0.4513 - val_accuracy: 0.8000
# Epoch 39/100
# 2/2 [==============================] - 1s 778ms/step - loss: 0.3925 - accuracy: 0.7895 - val_loss: 0.4404 - val_accuracy: 0.8000
# Epoch 40/100
# 2/2 [==============================] - 1s 770ms/step - loss: 0.4688 - accuracy: 0.7719 - val_loss: 0.4402 - val_accuracy: 0.8000
# Epoch 41/100
# 2/2 [==============================] - 1s 711ms/step - loss: 0.4150 - accuracy: 0.8421 - val_loss: 0.4368 - val_accuracy: 0.8000
# Epoch 42/100
# 2/2 [==============================] - 1s 690ms/step - loss: 0.4300 - accuracy: 0.7544 - val_loss: 0.4598 - val_accuracy: 0.8000
# Epoch 43/100
# 2/2 [==============================] - 1s 787ms/step - loss: 0.4491 - accuracy: 0.7193 - val_loss: 0.4846 - val_accuracy: 0.8000
# Epoch 44/100
# 2/2 [==============================] - 1s 802ms/step - loss: 0.4643 - accuracy: 0.8246 - val_loss: 0.4761 - val_accuracy: 0.8000
# Epoch 45/100
# 2/2 [==============================] - 1s 774ms/step - loss: 0.4494 - accuracy: 0.8246 - val_loss: 0.4591 - val_accuracy: 0.8000
# Epoch 46/100
# 2/2 [==============================] - 1s 775ms/step - loss: 0.4207 - accuracy: 0.8246 - val_loss: 0.4475 - val_accuracy: 0.8000
# Epoch 47/100
# 2/2 [==============================] - 1s 774ms/step - loss: 0.4853 - accuracy: 0.7895 - val_loss: 0.4456 - val_accuracy: 0.8000
# Epoch 48/100
# 2/2 [==============================] - 1s 663ms/step - loss: 0.3792 - accuracy: 0.8596 - val_loss: 0.4310 - val_accuracy: 0.8000
# Epoch 49/100
# 2/2 [==============================] - 1s 624ms/step - loss: 0.4359 - accuracy: 0.8421 - val_loss: 0.4300 - val_accuracy: 0.8000
# Epoch 50/100
# 2/2 [==============================] - 1s 732ms/step - loss: 0.3965 - accuracy: 0.8421 - val_loss: 0.4306 - val_accuracy: 0.8000
# Epoch 51/100
# 2/2 [==============================] - 1s 632ms/step - loss: 0.4566 - accuracy: 0.8070 - val_loss: 0.4253 - val_accuracy: 0.8000
# Epoch 52/100
# 2/2 [==============================] - 1s 723ms/step - loss: 0.4713 - accuracy: 0.8070 - val_loss: 0.4247 - val_accuracy: 0.8000
# Epoch 53/100
# 2/2 [==============================] - 1s 735ms/step - loss: 0.4673 - accuracy: 0.7719 - val_loss: 0.4530 - val_accuracy: 0.8000
# Epoch 54/100
# 2/2 [==============================] - 1s 644ms/step - loss: 0.4068 - accuracy: 0.8772 - val_loss: 0.4653 - val_accuracy: 0.7333
# Epoch 55/100
# 2/2 [==============================] - 1s 617ms/step - loss: 0.3878 - accuracy: 0.8421 - val_loss: 0.4327 - val_accuracy: 0.8000
# Epoch 56/100
# 2/2 [==============================] - 1s 671ms/step - loss: 0.4125 - accuracy: 0.8246 - val_loss: 0.3980 - val_accuracy: 0.8000
# Epoch 57/100
# 2/2 [==============================] - 2s 864ms/step - loss: 0.4031 - accuracy: 0.8070 - val_loss: 0.3908 - val_accuracy: 0.8000
# Epoch 58/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.4183 - accuracy: 0.7719 - val_loss: 0.4176 - val_accuracy: 0.8000
# Epoch 59/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.4421 - accuracy: 0.8070 - val_loss: 0.4184 - val_accuracy: 0.8000
# Epoch 60/100
# 2/2 [==============================] - 2s 964ms/step - loss: 0.4581 - accuracy: 0.7895 - val_loss: 0.4236 - val_accuracy: 0.8000
# Epoch 61/100
# 2/2 [==============================] - 1s 724ms/step - loss: 0.4581 - accuracy: 0.7719 - val_loss: 0.4200 - val_accuracy: 0.8000
# Epoch 62/100
# 2/2 [==============================] - 1s 930ms/step - loss: 0.4771 - accuracy: 0.7719 - val_loss: 0.4102 - val_accuracy: 0.8000
# Epoch 63/100
# 2/2 [==============================] - 1s 741ms/step - loss: 0.4074 - accuracy: 0.8070 - val_loss: 0.3869 - val_accuracy: 0.8000
# Epoch 64/100
# 2/2 [==============================] - 1s 854ms/step - loss: 0.3920 - accuracy: 0.8246 - val_loss: 0.3491 - val_accuracy: 0.8000
# Epoch 65/100
# 2/2 [==============================] - 1s 731ms/step - loss: 0.4452 - accuracy: 0.7719 - val_loss: 0.3680 - val_accuracy: 0.8000
# Epoch 66/100
# 2/2 [==============================] - 1s 726ms/step - loss: 0.4262 - accuracy: 0.7719 - val_loss: 0.4384 - val_accuracy: 0.7333
# Epoch 67/100
# 2/2 [==============================] - 1s 710ms/step - loss: 0.3985 - accuracy: 0.7719 - val_loss: 0.5142 - val_accuracy: 0.7333
# Epoch 68/100
# 2/2 [==============================] - 1s 840ms/step - loss: 0.3925 - accuracy: 0.8772 - val_loss: 0.5329 - val_accuracy: 0.6667
# Epoch 69/100
100
# 2/2 [==============================] - 2s 1s/step - loss: 0.4517 - accuracy: 0.7719 - val_loss: 0.2546 - val_accuracy: 0.9333
# Epoch 71/100
# 2/2 [==============================] - 2s 968ms/step - loss: 0.4665 - accuracy: 0.7719 - val_loss: 0.2700 - val_accuracy: 0.9333
# Epoch 72/100
# 2/2 [==============================] - 1s 805ms/step - loss: 0.4952 - accuracy: 0.7719 - val_loss: 0.2840 - val_accuracy: 0.9333
# Epoch 73/100
# 2/2 [==============================] - 2s 954ms/step - loss: 0.4016 - accuracy: 0.8421 - val_loss: 0.2878 - val_accuracy: 0.9333
# Epoch 74/100
# 2/2 [==============================] - 1s 862ms/step - loss: 0.4733 - accuracy: 0.8070 - val_loss: 0.2778 - val_accuracy: 0.9333
# Epoch 75/100
# 2/2 [==============================] - 1s 729ms/step - loss: 0.5166 - accuracy: 0.7719 - val_loss: 0.2646 - val_accuracy: 0.9333
# Epoch 76/100
# 2/2 [==============================] - 1s 732ms/step - loss: 0.5256 - accuracy: 0.6667 - val_loss: 0.2677 - val_accuracy: 0.9333
# Epoch 77/100
# 2/2 [==============================] - 1s 757ms/step - loss: 0.4618 - accuracy: 0.8070 - val_loss: 0.2667 - val_accuracy: 0.9333
# Epoch 78/100
# 2/2 [==============================] - 1s 715ms/step - loss: 0.4811 - accuracy: 0.7719 - val_loss: 0.2697 - val_accuracy: 0.9333
# Epoch 79/100
# 2/2 [==============================] - 1s 758ms/step - loss: 0.4569 - accuracy: 0.7193 - val_loss: 0.2855 - val_accuracy: 0.9333
# Epoch 80/100
# 2/2 [==============================] - 1s 836ms/step - loss: 0.5137 - accuracy: 0.7368 - val_loss: 0.3238 - val_accuracy: 0.8667
# Epoch 81/100
# 2/2 [==============================] - 1s 841ms/step - loss: 0.5130 - accuracy: 0.8070 - val_loss: 0.3139 - val_accuracy: 0.8667
# Epoch 82/100
# 2/2 [==============================] - 1s 849ms/step - loss: 0.4455 - accuracy: 0.7895 - val_loss: 0.2819 - val_accuracy: 0.9333
# Epoch 83/100
# 2/2 [==============================] - 1s 730ms/step - loss: 0.4618 - accuracy: 0.7895 - val_loss: 0.2773 - val_accuracy: 0.9333
# Epoch 84/100
# 2/2 [==============================] - 1s 718ms/step - loss: 0.3764 - accuracy: 0.7895 - val_loss: 0.2863 - val_accuracy: 0.9333
# Epoch 85/100
# 2/2 [==============================] - 1s 845ms/step - loss: 0.4409 - accuracy: 0.7719 - val_loss: 0.3127 - val_accuracy: 0.9333
# Epoch 86/100
# 2/2 [==============================] - 1s 710ms/step - loss: 0.4230 - accuracy: 0.8421 - val_loss: 0.3156 - val_accuracy: 0.9333
# Epoch 87/100
# 2/2 [==============================] - 1s 746ms/step - loss: 0.4122 - accuracy: 0.8070 - val_loss: 0.2912 - val_accuracy: 0.9333
# Epoch 88/100
# 2/2 [==============================] - 1s 721ms/step - loss: 0.4173 - accuracy: 0.8596 - val_loss: 0.2784 - val_accuracy: 0.9333
# Epoch 89/100
# 2/2 [==============================] - 1s 847ms/step - loss: 0.4376 - accuracy: 0.8070 - val_loss: 0.2780 - val_accuracy: 0.9333
# Epoch 90/100
# 2/2 [==============================] - 1s 852ms/step - loss: 0.4685 - accuracy: 0.7193 - val_loss: 0.2870 - val_accuracy: 0.9333
# Epoch 91/100
# 2/2 [==============================] - 1s 832ms/step - loss: 0.3660 - accuracy: 0.8596 - val_loss: 0.2991 - val_accuracy: 0.9333
# Epoch 92/100
# 2/2 [==============================] - 1s 848ms/step - loss: 0.4469 - accuracy: 0.7544 - val_loss: 0.2856 - val_accuracy: 0.9333
# Epoch 93/100
# 2/2 [==============================] - 1s 732ms/step - loss: 0.4733 - accuracy: 0.7544 - val_loss: 0.2674 - val_accuracy: 0.9333
# Epoch 94/100
# 2/2 [==============================] - 1s 751ms/step - loss: 0.4427 - accuracy: 0.7368 - val_loss: 0.2706 - val_accuracy: 0.9333
# Epoch 95/100
# 2/2 [==============================] - 1s 827ms/step - loss: 0.4418 - accuracy: 0.8421 - val_loss: 0.3072 - val_accuracy: 0.9333
# Epoch 96/100
# 2/2 [==============================] - 1s 849ms/step - loss: 0.4856 - accuracy: 0.7368 - val_loss: 0.3095 - val_accuracy: 0.9333
# Epoch 97/100
# 2/2 [==============================] - 1s 842ms/step - loss: 0.4738 - accuracy: 0.7544 - val_loss: 0.2764 - val_accuracy: 0.9333
# Epoch 98/100
# 2/2 [==============================] - 1s 860ms/step - loss: 0.3809 - accuracy: 0.8070 - val_loss: 0.2774 - val_accuracy: 0.9333
# Epoch 99/100
# 2/2 [==============================] - 1s 826ms/step - loss: 0.4483 - accuracy: 0.7895 - val_loss: 0.3034 - val_accuracy: 0.8667
# Epoch 100/100
# 2/2 [==============================] - 1s 842ms/step - loss: 0.5126 - accuracy: 0.7018 - val_loss: 0.3588 - val_accuracy: 0.8000

# %%
# classification report of test dataset of spiral:
y_pred_sp1 = model3.predict(test_sp)
pred_sp = np.argmax(y_pred_sp1,axis=1)
true_sp = np.argmax(tlables_sp,axis=1)
print(classification_report(true_sp,pred_sp))
# Out:
# 1/1 [==============================] - 1s 534ms/step
#               precision    recall  f1-score   support
#
#            0       0.74      0.93      0.82        15
#            1       0.91      0.67      0.77        15
#
#     accuracy                           0.80        30
#    macro avg       0.82      0.80      0.80        30
# weighted avg       0.82      0.80      0.80        30

# %%
# classification report of test dataset of wave:
y_pred_wa1 = model4.predict(test_wa)
pred_wa = np.argmax(y_pred_wa1,axis=1)
true_wa = np.argmax(tlables_wa,axis=1)
print(classification_report(true_wa,pred_wa))
# Out:
# 1/1 [==============================] - 1s 609ms/step
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        15
#            1       1.00      0.80      0.89        15
#
#     accuracy                           0.90        30
#    macro avg       0.92      0.90      0.90        30
# weighted avg       0.92      0.90      0.90        30

# %%
# plotting the accuracy and loss of spiral training and validation dataset:
get_acc3 = sp_3.history['accuracy']
value_acc3 = sp_3.history['val_accuracy']
get_loss3 = sp_3.history['loss']
validation_loss3 = sp_3.history['val_loss']

epochs3 = range(len(get_acc3))
plt.plot(epochs3, get_acc3, 'r',label='Accuracy of Training data')
plt.plot(epochs3, value_acc3, 'b',label='Accuracy of Validation data')
plt.title("Training vs validation accuracy - Spiral")
plt.legend(loc=0)
plt.figure()
plt.show()
epochs3 = range(len(get_loss3))
plt.plot(epochs3, get_loss3, 'r',label='Loss of Training data')
plt.plot(epochs3, validation_loss3, 'b',label='Loss of Validation data')
plt.title("Training vs validation loss - Spiral")
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
# plotting the accuracy and loss of wave training and validation dataset:
get_acc4 = wa_4.history['accuracy']
value_acc4 = wa_4.history['val_accuracy']
get_loss4 = wa_4.history['loss']
validation_loss4 = wa_4.history['val_loss']

epochs4 = range(len(get_acc4))
plt.plot(epochs4, get_acc4, 'r',label='Accuracy of Training data')
plt.plot(epochs4, value_acc4, 'b',label='Accuracy of Validation data')
plt.title("Training vs validation accuracy - Wave")
plt.legend(loc=0)
plt.figure()
plt.show()
epochs4 = range(len(get_loss4))
plt.plot(epochs4, get_loss4, 'r',label='Loss of Training data')
plt.plot(epochs4, validation_loss4, 'b',label='Loss of Validation data')
plt.title("Training vs validation loss - Wave")
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
# MobileNetV2:
pretrained_model5 = tf.keras.applications.MobileNetV2(input_shape=(100,100,3),include_top=False,weights='imagenet',pooling='avg')
pretrained_model5.trainable = False

pretrained_model6 = tf.keras.applications.MobileNetV2(input_shape=(100,100,3),include_top=False,weights='imagenet',pooling='avg')
pretrained_model6.trainable = False
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
# intializing last layer and output layer:
inputs5 = pretrained_model5.input
x5 = tf.keras.layers.Dense(128,activation='relu')(pretrained_model5.output)
outputs5 = tf.keras.layers.Dense(2,activation='softmax')(x5)
model5 = tf.keras.Model(inputs=inputs5, outputs=outputs5)

inputs6 = pretrained_model6.input
x6 = tf.keras.layers.Dense(128,activation='relu')(pretrained_model6.output)
outputs6 = tf.keras.layers.Dense(2,activation='softmax')(x6)
model6 = tf.keras.Model(inputs=inputs6, outputs=outputs6)

model5.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model6.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
# fitting and predictions on spiral and wave dataset:
sp_5=model5.fit(datagen.flow(trainx_sp,trainy_sp,batch_size=32),validation_data=(validx_sp,validy_sp),epochs=100)
wa_6=model6.fit(datagen.flow(trainx_wa,trainy_wa,batch_size=32),validation_data=(validx_wa,validy_wa),epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 3s 1s/step - loss: 1.8130 - accuracy: 0.4561 - val_loss: 1.4619 - val_accuracy: 0.4000
# Epoch 2/100
# 2/2 [==============================] - 0s 158ms/step - loss: 1.3251 - accuracy: 0.5263 - val_loss: 0.6888 - val_accuracy: 0.6000
# Epoch 3/100
# 2/2 [==============================] - 0s 168ms/step - loss: 0.8098 - accuracy: 0.5263 - val_loss: 0.6141 - val_accuracy: 0.6000
# Epoch 4/100
# 2/2 [==============================] - 0s 197ms/step - loss: 0.6156 - accuracy: 0.5614 - val_loss: 0.6373 - val_accuracy: 0.6667
# Epoch 5/100
# 2/2 [==============================] - 0s 182ms/step - loss: 0.5174 - accuracy: 0.7018 - val_loss: 0.7457 - val_accuracy: 0.6667
# Epoch 6/100
# 2/2 [==============================] - 0s 193ms/step - loss: 0.5431 - accuracy: 0.7018 - val_loss: 0.5725 - val_accuracy: 0.6667
# Epoch 7/100
# 2/2 [==============================] - 0s 152ms/step - loss: 0.
- val_accuracy: 1.0000
# Epoch 86/100
# 2/2 [==============================] - 0s 216ms/step - loss: 0.4449 - accuracy: 0.7719 - val_loss: 0.2707 - val_accuracy: 1.0000
# Epoch 87/100
# 2/2 [==============================] - 0s 143ms/step - loss: 0.3949 - accuracy: 0.7719 - val_loss: 0.3425 - val_accuracy: 0.8000
# Epoch 88/100
# 2/2 [==============================] - 0s 178ms/step - loss: 0.4855 - accuracy: 0.8246 - val_loss: 0.3767 - val_accuracy: 0.8000
# Epoch 89/100
# 2/2 [==============================] - 0s 187ms/step - loss: 0.3710 - accuracy: 0.8421 - val_loss: 0.3629 - val_accuracy: 0.8000
# Epoch 90/100
# 2/2 [==============================] - 0s 189ms/step - loss: 0.3612 - accuracy: 0.8070 - val_loss: 0.3464 - val_accuracy: 0.8000
# Epoch 91/100
# 2/2 [==============================] - 0s 237ms/step - loss: 0.4416 - accuracy: 0.8421 - val_loss: 0.2865 - val_accuracy: 0.8667
# Epoch 92/100
# 2/2 [==============================] - 0s 172ms/step - loss: 0.3860 - accuracy: 0.8421 - val_loss: 0.2803 - val_accuracy: 0.8667
# Epoch 93/100
# 2/2 [==============================] - 0s 184ms/step - loss: 0.3359 - accuracy: 0.8421 - val_loss: 0.2833 - val_accuracy: 0.8667
# Epoch 94/100
# 2/2 [==============================] - 0s 192ms/step - loss: 0.4405 - accuracy: 0.7193 - val_loss: 0.2829 - val_accuracy: 0.9333
# Epoch 95/100
# 2/2 [==============================] - 0s 149ms/step - loss: 0.2611 - accuracy: 0.9123 - val_loss: 0.3074 - val_accuracy: 0.8667
# Epoch 96/100
# 2/2 [==============================] - 0s 193ms/step - loss: 0.4688 - accuracy: 0.8070 - val_loss: 0.3171 - val_accuracy: 0.8667
# Epoch 97/100
# 2/2 [==============================] - 0s 159ms/step - loss: 0.3472 - accuracy: 0.8596 - val_loss: 0.2751 - val_accuracy: 1.0000
# Epoch 98/100
# 2/2 [==============================] - 0s 173ms/step - loss: 0.3407 - accuracy: 0.8772 - val_loss: 0.2574 - val_accuracy: 0.9333
# Epoch 99/100
# 2/2 [==============================] - 0s 192ms/step - loss: 0.3056 - accuracy: 0.8947 - val_loss: 0.2394 - val_accuracy: 1.0000
# Epoch 100/100
# 2/2 [==============================] - 0s 176ms/step - loss: 0.2849 - accuracy: 0.8947 - val_loss: 0.2643 - val_accuracy: 0.8667

# %%
# classification report of test dataset of spiral:
y_pred_sp2 = model5.predict(test_sp)
pred_sp = np.argmax(y_pred_sp2,axis=1)
ground_sp = np.argmax(tlables_sp,axis=1)
print(classification_report(ground_sp,pred_sp))
# Out:
# 1/1 [==============================] - 1s 631ms/step
#               precision    recall  f1-score   support
#
#            0       0.65      1.00      0.79        15
#            1       1.00      0.47      0.64        15
#
#     accuracy                           0.73        30
#    macro avg       0.83      0.73      0.71        30
# weighted avg       0.83      0.73      0.71        30

# %%
# classification report of test dataset of wave:
y_pred_wa2 = model6.predict(test_wa)
pred_wa = np.argmax(y_pred_wa2,axis=1)
ground_wa = np.argmax(tlables_wa,axis=1)
print(classification_report(ground_wa,pred_wa))
# Out:
# 1/1 [==============================] - 1s 665ms/step
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        15
#            1       0.93      0.93      0.93        15
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30

# %%
# plotting the accuracy and loss of spiral training and validation dataset:
get_acc5 = sp_5.history['accuracy']
value_acc5 = sp_5.history['val_accuracy']
get_loss5 = sp_5.history['loss']
validation_loss5 = sp_5.history['val_loss']

epochs5 = range(len(get_acc5))
plt.plot(epochs5, get_acc5, 'r',label='Accuracy of Training data')
plt.plot(epochs5, value_acc5, 'b',label='Accuracy of Validation data')
plt.title("Training vs validation accuracy - Spiral")
plt.legend(loc=0)
plt.figure()
plt.show()
epochs5 = range(len(get_loss5))
plt.plot(epochs5, get_loss5, 'r',label='Loss of Training data')
plt.plot(epochs5, validation_loss5, 'b',label='Loss of Validation data')
plt.title("Training vs validation loss - Spiral")
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
# plotting the accuracy and loss of wave training and validation dataset:
get_acc6 = wa_6.history['accuracy']
value_acc6 = wa_6.history['val_accuracy']
get_loss6 = wa_6.history['loss']
validation_loss6 = wa_6.history['val_loss']

epochs6 = range(len(get_acc6))
plt.plot(epochs6, get_acc6, 'r',label='Accuracy of Training data')
plt.plot(epochs6, value_acc6, 'b',label='Accuracy of Validation data')
plt.title("Training vs validation accuracy - Wave")
plt.legend(loc=0)
plt.figure()
plt.show()
epochs6 = range(len(get_loss6))
plt.plot(epochs6, get_loss6, 'r',label='Loss of Training data')
plt.plot(epochs6, validation_loss6, 'b',label='Loss of Validation data')
plt.title("Training vs validation loss - Wave")
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
# DenseNet201:
pretrained_model7 = tf.keras.applications.DenseNet201(input_shape=(100,100,3),include_top=False,weights='imagenet',pooling='avg')
pretrained_model7.trainable = False

pretrained_model8 = tf.keras.applications.DenseNet201(input_shape=(100,100,3),include_top=False,weights='imagenet',pooling='avg')
pretrained_model8.trainable = False

# %%
# intializing last layer and output layer:
inputs7 = pretrained_model7.input
x7 = tf.keras.layers.Dense(128,activation='relu')(pretrained_model7.output)
outputs7 = tf.keras.layers.Dense(2,activation='softmax')(x7)
model7 = tf.keras.Model(inputs=inputs7, outputs=outputs7)

inputs8 = pretrained_model8.input
x8 = tf.keras.layers.Dense(128,activation='relu')(pretrained_model8.output)
outputs8 = tf.keras.layers.Dense(2,activation='softmax')(x8)
model8 = tf.keras.Model(inputs=inputs8, outputs=outputs8)

model7.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model8.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
# fitting and predictions on spiral and wave dataset:
sp_7=model7.fit(datagen.flow(trainx_sp,trainy_sp,batch_size=32),validation_data=(validx_sp,validy_sp),epochs=100)
wa_8=model8.fit(datagen.flow(trainx_wa,trainy_wa,batch_size=32),validation_data=(validx_wa,validy_wa),epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 13s 3s/step - loss: 1.0262 - accuracy: 0.6140 - val_loss: 1.7554 - val_accuracy: 0.4000
# Epoch 2/100
# 2/2 [==============================] - 1s 717ms/step - loss: 0.9589 - accuracy: 0.5439 - val_loss: 0.6773 - val_accuracy: 0.6000
# Epoch 3/100
# 2/2 [==============================] - 1s 902ms/step - loss: 0.8058 - accuracy: 0.4737 - val_loss: 0.5291 - val_accuracy: 0.6667
# Epoch 4/100
# 2/2 [==============================] - 1s 713ms/step - loss: 0.7291 - accuracy: 0.5614 - val_loss: 0.8098 - val_accuracy: 0.6667
# Epoch 5/100
# 2/2 [==============================] - 1s 781ms/step - loss: 0.6796 - accuracy: 0.6842 - val_loss: 0.6214 - val_accuracy: 0.6667
# Epoch 6/100
# 2/2 [==============================] - 1s 820ms/step - loss: 0.5738 - accuracy: 0.7018 - val_loss: 0.4526 - val_accuracy: 0.8000
# Epoch 7/100
# 2/2 [==============================] - 1s 949ms/step - loss: 0.5419 - accuracy: 0.7719 - val_loss: 0.4593 - val_accuracy: 0.6667
# Epoch 8/100
# 2/2 [==============================] - 1s 692ms/step - loss: 0.4494 - accuracy: 0.8421 - val_loss: 0.4492 - val_accuracy: 0.8000
# Epoch 9/100
# 2/2 [==============================] - 1s 685ms/step - loss: 0.4770 - accuracy: 0.8070 - val_loss: 0.5613 - val_accuracy: 0.6667
# Epoch 10/100
# 2/2 [==============================] - 1s 849ms/step - loss: 0.5254 - accuracy: 0.7719 - val_loss: 0.4797 - val_accuracy: 0.6667
# Epoch 11/100
# 2/2 [==============================] - 1s 808ms/step - loss: 0.4827 - accuracy: 0.7544 - val_loss: 0.4206 - val_accuracy: 0.8667
# Epoch 12/100
# 2/2 [==============================] - 1s 779ms/step - loss: 0.4223 - accuracy: 0.8246 - val_loss: 0.4329 - val_accuracy: 0.8000
# Epoch 13/100
# 2/2 [==============================] - 1s 926ms/step - loss: 0.4214 - accuracy: 0.8246 - val_loss: 0.4253 - val_accuracy: 0.8000
# Epoch 14/100
# 2/2 [==============================] - 1s 777ms/step - loss: 0.4460 - accuracy: 0.7719 - val_loss: 0.5075 - val_accuracy: 0.6667
# Epoch 15/100
# 2/2 [==============================] - 1s 914ms/step - loss: 0.4191 - accuracy: 0.7895 - val_loss: 0.4187 - val_accuracy: 0.8000
# Epoch 16/100
# 2/2 [==============================] - 1s 817ms/step - loss: 0.3919 - accuracy: 0.8246 - val_loss: 0.4179 - val_accuracy: 0.8000
# Epoch 17/100
# 2/2 [==============================] - 1s 722ms/step - loss: 0.5019 - accuracy: 0.7719 - val_loss: 0.3882 - val_accuracy: 0.8667
# Epoch 18/100
# 2/2 [==============================] - 1s 748ms/step - loss: 0.3418 - accuracy: 0.8772 - val_loss: 0.4344 - val_accuracy: 0.7333
# Epoch 19/100
# 2/2 [==============================] - 1s 916ms/step - loss: 0.3537 - accuracy: 0.8772 - val_loss: 0.4236 - val_accuracy: 0.8000
# Epoch 20/100
# 2/2 [==============================] - 1s 841ms/step - loss: 0.3671 - accuracy: 0.8772 - val_loss: 0.3624 - val_accuracy: 0.8667
# Epoch 21/100
# 2/2 [==============================] - 1s 819ms/step - loss: 0.3506 - accuracy: 0.8947 - val_loss: 0.3671 - val_accuracy: 0.8667
# Epoch 22/100
# 2/2 [==============================] - 1s 805ms/step - loss: 0.4523 - accuracy: 0.8246 - val_loss: 0.3588 - val_accuracy: 0.8667
# Epoch 23/100
# 2/2 [==============================] - 1s 816ms/step - loss: 0.4306 - accuracy: 0.8070 - val_loss: 0.4217 - val_accuracy: 0.8000
# Epoch 24/100
# 2/2 [==============================] - 1s 809ms/step - loss: 0.3232 - accuracy: 0.8772 - val_loss: 0.3913 - val_accuracy: 0.8000
# Epoch 25/100
# 2/2 [==============================] - 1s 638ms/step - loss: 0.4016 - accuracy: 0.7895 - val_loss: 0.3714 - val_accuracy: 0.8000
# Epoch 26/100
# 2/2 [==============================] - 1s 831ms/step - loss: 0.3760 - accuracy: 0.8246 - val_loss: 0.4035 - val_accuracy: 0.8000
# Epoch 27/100
# 2/2 [==============================] - 1s 747ms/step - loss: 0.3448 - accuracy: 0.8596 - val_loss: 0.3591 - val_accuracy: 0.8667
# Epoch 28/100
# 2/2 [==============================] - 1s 803ms/step - loss: 0.3216 - accuracy: 0.8772 - val_loss: 0.3928 - val_accuracy: 0.8000
# Epoch 29/100
# 2/2 [==============================] - 1s 709ms/step - loss: 0.3142 - accuracy: 0.8596 - val_loss: 0.3753 - val_accuracy: 0.8000
# Epoch 30/100
# 2/2 [==============================] - 1s 836ms/step - loss: 0.3985 - accuracy: 0.8772 - val_loss: 0.3861 - val_accuracy: 0.7333
# Epoch 31/100
# 2/2 [==============================] - 1s 799ms/step - loss: 0.3176 - accuracy: 0.8246 - val_loss: 0.4014 - val_accuracy: 0.7333
# Epoch 32/100
# 2/2 [==============================] - 1s 693ms/step - loss: 0.2957 - accuracy: 0.9123 - val_loss: 0.3591 - val_accuracy: 0.8000
# Epoch 33/100
# 2/2 [==============================] - 1s 607ms/step - loss: 0.2720 - accuracy: 0.8947 - val_loss: 0.3931 - val_accuracy: 0.8667
# Epoch 34/100
# 2/2 [==============================] - 1s 788ms/step - loss: 0.3420 - accuracy: 0.8772 - val_loss: 0.3672 - val_accuracy: 0.8000
# Epoch 35/100
# 2/2 [==============================] - 1s 750ms/step - loss: 0.3253 - accuracy: 0.8772 - val_loss: 0.3454 - val_accuracy: 0.7333
# Epoch 36/100
# 2/2 [==============================] - 1s 586ms/step - loss: 0.3019 - accuracy: 0.8947 - val_loss: 0.3533 - val_accuracy: 0.8000
# Epoch 37/100
# 2/2 [==============================] - 1s 706ms/step - loss: 0.3566 - accuracy: 0.8772 - val_loss: 0.3349 - val_accuracy: 0.8000
# Epoch 38/100
# 2/2 [==============================] - 1s 719ms/step - loss: 0.2939 - accuracy: 0.8772 - val_loss: 0.3698 - val_accuracy: 0.8667
# Epoch 39/100
# 2/2 [==============================] - 1s 576ms/step - loss: 0.3380 - accuracy: 0.8421 - val_loss: 0.3353 - val_accuracy: 0.8667
# Epoch 40/100
# 2/2 [==============================] - 1s 602ms/step - loss: 0.2682 - accuracy: 0.9298 - val_loss: 0.3238 - val_accuracy: 0.7333
# Epoch 41/100
# 2/2 [==============================] - 1s 656ms/step - loss: 0.2782 - accuracy: 0.8596 - val_loss: 0.3819 - val_accuracy: 0.8000
# Epoch 42/100
# 2/2 [==============================] - 1s 764ms/step - loss: 0.3577 - accuracy: 0.8070 - val_loss: 0.3096 - val_accuracy: 0.7333
# Epoch 43/100
# 2/2 [==============================] - 1s 726ms/step - loss: 0.2547 - accuracy: 0.8772 - val_loss: 0.3616 - val_accuracy: 0.8667
# Epoch 44/100
# 2/2 [==============================] - 1s 589ms/step - loss: 0.2946 - accuracy: 0.8772 - val_loss: 0.3129 - val_accuracy: 0.8667
# Epoch 45/100
# 2/2 [==============================] - 1s 583ms/step - loss: 0.3439 - accuracy: 0.8772 - val_loss: 0.4049 - val_accuracy: 0.8000
# Epoch 46/100
# 2/2 [==============================] - 1s 686ms/step - loss: 0.3226 - accuracy: 0.8596 - val_loss: 0.3296 - val_accuracy: 0.8000
# Epoch 47/100
# 2/2 [==============================] - 1s 579ms/step - loss: 0.2885 - accuracy: 0.8246 - val_loss: 0.3074 - val_accuracy: 0.8000
# Epoch 48/100
# 2/2 [==============================] - 1s 578ms/step - loss: 0.2781 - accuracy: 0.8246 - val_loss: 0.3318 - val_accuracy: 0.8000
# Epoch 49/100
# 2/2 [==============================] - 1s 762ms/step - loss: 0.2696 - accuracy: 0.8772 - val_loss: 0.4787 - val_accuracy: 0.8000
# Epoch 50/100
# 2/2 [==============================] - 1s 574ms/step - loss: 0.3342 - accuracy: 0.8421 - val_loss: 0.3002 - val_accuracy: 0.8667
# Epoch 51/100
# 2/2 [==============================] - 1s 571ms/step - loss: 0.3082 - accuracy: 0.8772 - val_loss: 0.2647 - val_accuracy: 0.8000
# Epoch 52/100
# 2/2 [==============================] - 1s 587ms/step - loss: 0.2637 - accuracy: 0.8947 - val_loss: 0.2608 - val_accuracy: 0.8000
# Epoch 53/100
# 2/2 [==============================] - 1s 751ms/step - loss: 0.2539 - accuracy: 0.9298 - val_loss: 0.2748 - val_accuracy: 0.8667
# Epoch 54/100
# 2/2 [==============================] - 1s 818ms/step - loss: 0.2300 - accuracy: 0.9649 - val_loss: 0.3812 - val_accuracy: 0.8667
# Epoch 55/100
# 2/2 [==============================] - 1s 801ms/step - loss: 0.3288 - accuracy: 0.8947 - val_loss: 0.2730 - val_accuracy: 0.8000
# Epoch 56/100
# 2/2 [==============================] - 1s 799ms/step - loss: 0.2542 - accuracy: 0.8947 - val_loss: 0.2692 - val_accuracy: 0.7333
# Epoch 57/100
# 2/2 [==============================] - 1s 790ms/step - loss: 0.2947 - accuracy: 0.9123 - val_loss: 0.2674 - val_accuracy: 0.7333
# Epoch 58/100
# 2/2 [==============================] - 1s 620ms/step - loss: 0.2655 - accuracy: 0.8772 - val_loss: 0.2923 - val_accuracy: 0.8667
# Epoch 59/100
# 2/2 [==============================] - 1s 616ms/step - loss: 0.1869 - accuracy: 0.9649 - val_loss: 0.2595 - val_accuracy: 0.7333
# Epoch 60/100
# 2/2 [==============================] - 1s 624ms/step - loss: 0.2383 - accuracy: 0.9298 - val_loss: 0.2641 - val_accuracy: 0.8000
# Epoch 61/100
# 2/2 [==============================] - 1s 753ms/step - loss: 0.2455 - accuracy: 0.9123 - val_loss: 0.2661 - val_accuracy: 0.8000
# Epoch 62/100
# 2/2 [==============================] - 1s 768ms/step - loss: 0.3283 - accuracy: 0.8421 - val_loss: 0.2748 - val_accuracy: 0.8000
# Epoch 63/100
# 2/2 [==============================] - 1s 810ms/step - loss: 0.1923 - accuracy: 0.9649 - val_loss: 0.3291 - val_accuracy: 0.8667
# Epoch 64/100
# 2/2 [==============================] - 1s 780ms/step - loss: 0.2224 - accuracy: 0.8947 - val_loss: 0.3369 - val_accuracy: 0.8667
# Epoch 65/100
# 2/2 [==============================] - 1s 603ms/step - loss: 0.2024 - accuracy: 0.9474 - val_loss: 0.2785 - val_accuracy: 0.8667
# Epoch 66/100
# 2/2 [==============================] - 1s 746ms/step - loss: 0.2096 - accuracy: 0.8947 - val_loss: 0.2869 - val_accuracy: 0.7333
# Epoch 67/100
# 2/2 [==============================] - 1s 774ms/step - loss: 0.2649 - accuracy: 0.8772 - val_loss: 0.3052 - val_accuracy: 0.8667
# Epoch 68/100
# 2/2 [==============================] - 1s 558ms/step - loss: 0.2651 - accuracy: 0.9298 - val_loss: 0.3321 - val_accuracy: 0.8667
# Epoch 69/100
# 2/2 [==============================] - 1s 674ms/step - loss: 0.2369 - accuracy: 0.9123 - val_loss: 0.3067 - val_accuracy: 0.8667
# Epoch 70/100
# 2/2 [==============================] - 1s 669ms/step - loss: 0.3013 - accuracy: 0.9298 - val_loss: 0.3074 - val_accuracy: 0.8667
# Epoch 71/100
# 2/2 [==============================] - 1s 680ms/step - loss: 0.2697 - accuracy: 0.8947 - val_loss: 0.2895 - val_accuracy: 0.8000
# Epoch 72/100
# 2/2 [==============================] - 1s 760ms/step - loss: 0.2426 - accuracy: 0.8947 - val_loss: 0.3164 - val_accuracy: 0.8667
# Epoch 73/100
# 2/2 [==============================] - 1s 524ms/step - loss: 0.2359 - accuracy: 0.9123 - val_loss: 0.3050 - val_accuracy: 0.8667
# Epoch 74/100
# 2/2 [==============================] - 1s 739ms/step - loss: 0.1942 - accuracy: 0.9298 - val_loss: 0.2776 - val_accuracy: 0.8000
# Epoch 75/100
# 2/2 [==============================] - 1s 777ms/step - loss: 0.2612 - accuracy: 0.8772 - val_loss: 0.2791 - val_accuracy: 0.8667
# Epoch 76/100
# 2/2 [==============================] - 1s 731ms/step - loss: 0.2785 - accuracy: 0.8596 - val_loss: 0.3055 - val_accuracy: 0.8667
# Epoch 77/100
# 2/2 [==============================] - 1s 787ms/step - loss: 0.2956 - accuracy: 0.9123 - val_loss: 0.2732 - val_accuracy: 0.8000
# Epoch 78/100
# 2/2 [==============================] - 1s 587ms/step - loss: 0.1666 - accuracy: 0.9649 - val_loss: 0.2766 - val_accuracy: 0.8667
# Epoch 79/100
# 2/2 [==============================] - 1s 989ms/step - loss: 0.2911 - accuracy: 0.8947 - val_loss: 0.2631 - val_accuracy: 0.8000
# Epoch 80/100
# 2/2 [==============================] - 1s 925ms/step - loss: 0.1925 - accuracy: 0.9298 - val_loss: 0.2582 - val_accuracy: 0.8000
# Epoch 81/100
# 2/2 [==============================] - 2s 862ms/step - loss: 0.2507 - accuracy: 0.9298 - val_loss: 0.2580 - val_accuracy: 0.8000
# Epoch 82/100
# 2/2 [==============================] - 1s 888ms/step - loss: 0.1766 - accuracy: 0.9474 - val_loss: 0.2690 - val_accuracy: 0.8667
# Epoch 83/100
# 2/2 [==============================] - 1s 803ms/step - loss: 0.3590 - accuracy: 0.8596 - val_loss: 0.2364 - val_accuracy: 0.8000
# Epoch 84/100
# 2/2 [==============================] - 1s 720ms/step - loss: 0.2115 - accuracy: 0.9123 - val_loss: 0.2655 - val_accuracy: 0.8667
# Epoch 85/100
# 2/2 [==============================] - 1s 946ms/step - loss: 0.2710 - accuracy: 0.8947 - val_loss: 0.2372 - val_accuracy: 0.8000
# Epoch 86/100
# 2/2 [==============================] - 1s 869ms/step - loss: 0.1797 - accuracy: 0.9298 - val_loss: 0.2565 - val_accuracy: 0.9333
# Epoch 87/100
# 2/2 [==============================] - 1s 669ms/step - loss: 0.2073 - accuracy: 0.8947 - val_loss: 0.2483 - val_accuracy: 0.8000
# Epoch 88/100
# 2/2 [==============================] - 1s 693ms/step - loss: 0.2389 - accuracy: 0.9123 - val_loss: 0.2572 - val_accuracy: 0.8000
# Epoch 89/100
# 2/2 [==============================] - 1s 915ms/step - loss: 0.2036 - accuracy: 0.9123 - val_loss: 0.2490 - val_accuracy: 0.8000
# Epoch 90/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.2552 - accuracy: 0.9123 - val_loss: 0.2413 - val_accuracy: 0.8667
# Epoch 91/100
# 2/2 [==============================] - 1s 907ms/step - loss: 0.2023 - accuracy: 0.9123 - val_loss: 0.2373 - val_accuracy: 0.8667
# Epoch 92/100
# 2/2 [==============================] - 1s 756ms/step - loss: 0.1953 - accuracy: 0.9123 - val_loss: 0.3111 - val_accuracy: 0.8667
# Epoch 93/100
# 2/2 [==============================] - 2s 938ms/step - loss: 0.2724 - accuracy: 0.9123 - val_loss: 0.3579 - val_accuracy: 0.8667
# Epoch 94/100
# 2/2 [==============================] - 1s 908ms/step - loss: 0.1938 - accuracy: 0.9298 - val_loss: 0.2264 - val_accuracy: 0.8000
# Epoch 95/100
# 2/2 [==============================] - 1s 691ms/step - loss: 0.2538 - accuracy: 0.9123 - val_loss: 0.2284 - val_accuracy: 0.8000
# Epoch 96/100
# 2/2 [==============================] - 1s 683ms/step - loss: 0.2721 - accuracy: 0.9123 - val_loss: 0.2765 - val_accuracy: 0.8667
# Epoch 97/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.2359 - accuracy: 0.9474 - val_loss: 0.3076 - val_accuracy: 0.8667
# Epoch 98/100
# 2/2 [==============================] - 2s 831ms/step - loss: 0.2750 - accuracy: 0.8772 - val_loss: 0.2779 - val_accuracy: 0.8667
# Epoch 99/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.2337 - accuracy: 0.9123 - val_loss: 0.2497 - val_accuracy: 0.8667
# Epoch 100/100
# 2/2 [==============================] - 2s 1s/step - loss: 0.1771 - accuracy: 0.9123 - val_loss: 0.2571 - val_accuracy: 0.8667
# Epoch 1/100
# 2/2 [==============================] - 13s 3s/step - loss: 0.7320 - accuracy: 0.4561 - val_loss: 0.7318 - val_accuracy: 0.5333
# Epoch 2/100
# 2/2 [==============================] - 1s 792ms/step - loss: 0.7422 - accuracy: 0.5439 - val_loss: 0.4010 - val_accuracy: 0.9333
# Epoch 3/100
# 2/2 [==============================] - 1s 711ms/step - loss: 0.5351 - accuracy: 0.7719 - val_loss: 0.3408 - val_accuracy: 0.9333
# Epoch 4/100
# 2/2 [==============================] - 1s 777ms/step - loss: 0.4344 - accuracy: 0.8246 - val_loss: 0.2954 - val_accuracy: 0.9333
# Epoch 5/100
# 2/2 [==============================] - 1s 633ms/step - loss: 0.5134 - accuracy: 0.7193 - val_loss: 0.2284 - val_accuracy: 0.9333
# Epoch 6/100
# 2/2 [==============================] - 1s 729ms/step - loss: 0.4228 - accuracy: 0.8246 - val_loss: 0.2316 - val_accuracy: 0.9333
# Epoch 7/100
# 2/2 [==============================] - 1s 582ms/step - loss: 0.5266 - accuracy: 0.8246 - val_loss: 0.1872 - val_accuracy: 1.0000
# Epoch 8/100
# 2/2 [==============================] - 1s 618ms/step - loss: 0.4897 - accuracy: 0.8070 - val_loss: 0.1692 - val_accuracy: 1.0000
# Epoch 9/100
# 2/2 [==============================] - 1s 624ms/step - loss: 0.3112 - accuracy: 0.8947 - val_loss: 0.1666 - val_accuracy: 0.9333
# Epoch 10/100
# 2/2 [==============================] - 1s 758ms/step - loss: 0.3853 - accuracy: 0.7895 - val_loss: 0.1910 - val_accuracy: 0.9333
# Epoch 11/100
# 2/2 [==============================] - 1s 772ms/step - loss: 0.4561 - accuracy: 0.8070 - val_loss: 0.1589 - val_accuracy: 0.9333
# Epoch 12/100
# 2/2 [==============================] - 1s 909ms/step - loss: 0.4256 - accuracy: 0.7895 - val_loss: 0.1536 - val_accuracy: 0.9333
# Epoch 13/100
# 2/2 [==============================] - 1s 562ms/step - loss: 0.3888 - accuracy: 0.8246 - val_loss: 0.1451 - val_accuracy: 1.0000
# Epoch 14/100
# 2/2 [==============================] - 1s 530ms/step - loss: 0.4033 - accuracy: 0.8070 - val_loss: 0.1195 - val_accuracy: 1.0000
# Epoch 15/100
# 2/2 [==============================] - 1s 649ms/step - loss: 0.3488 - accuracy: 0.8421 - val_loss: 0.1267 - val_accuracy: 1.0000
# Epoch 16/100
# 2/2 [==============================] - 1s 534ms/step - loss: 0.3965 - accuracy: 0.8421 - val_loss: 0.1267 - val_accuracy: 1.0000
# Epoch 17/100
# 2/2 [==============================] - 1s 645ms/step - loss: 0.3096 - accuracy: 0.8772 - val_loss: 0.1355 - val_accuracy: 1.0000
# Epoch 18/100
# 2/2 [==============================] - 1s 564ms/step - loss: 0.3526 - accuracy: 0.8772 - val_loss: 0.1379 - val_accuracy: 1.0000
# Epoch 19/100
# 2/2 [==============================] - 1s 584ms/step - loss: 0.3681 - accuracy: 0.7544 - val_loss: 0.1457 - val_accuracy: 0.9333
# Epoch 20/100
# 2/2 [==============================] - 1s 806ms/step - loss: 0.2806 - accuracy: 0.8947 - val_loss: 0.1620 - val_accuracy: 0.9333
# Epoch 21/100
# 2/2 [==============================] - 1s 603ms/step - loss: 0.4267 - accuracy: 0.8070 - val_loss: 0.1464 - val_accuracy: 0.9333
# Epoch 22/100
# 2/2 [==============================] - 1s 780ms/step - loss: 0.2249 - accuracy: 0.9123 - val_loss: 0.1326 - val_accuracy: 1.0000
# Epoch 23/100
# 2/2 [==============================] - 1s 764ms/step - loss: 0.4137 - accuracy: 0.7895 - val_loss: 0.1323 - val_accuracy: 1.0000
# Epoch 24/100
# 2/2 [==============================] - 1s 745ms/step - loss: 0.3342 - accuracy: 0.8596 - val_loss: 0.1199 - val_accuracy: 1.0000
# Epoch 25/100
# 2/2 [==============================] - 1s 766ms/step - loss: 0.2894 - accuracy: 0.9123 - val_loss: 0.1361 - val_accuracy: 0.9333
# Epoch 26/100
# 2/2 [==============================] - 1s 641ms/step - loss: 0.3890 - accuracy: 0.8421 - val_loss: 0.1228 - val_accuracy: 1.0000
# Epoch 27/100
# 2/2 [==============================] - 1s 580ms/step - loss: 0.2786 - accuracy: 0.8947 - val_loss: 0.1019 - val_accuracy: 1.0000
# Epoch 28/100
# 2/2 [==============================] - 1s 659ms/step - loss: 0.3717 - accuracy: 0.8421 - val_loss: 0.0985 - val_accuracy: 1.0000
# Epoch 29/100
# 2/2 [==============================] - 1s 740ms/step - loss: 0.2570 - accuracy: 0.8947 - val_loss: 0.1414 - val_accuracy: 0.9333
# Epoch 30/100
# 2/2 [==============================] - 1s 623ms/step - loss: 0.2898 - accuracy: 0.8421 - val_loss: 0.1386 - val_accuracy: 0.9333
# Epoch 31/100
# 2/2 [==============================] - 1s 781ms/step - loss: 0.2763 - accuracy: 0.8947 - val_loss: 0.0835 - val_accuracy: 1.0000
# Epoch 32/100
# 2/2 [==============================] - 1s 620ms/step - loss: 0.3654 - accuracy: 0.8421 - val_loss: 0.0721 - val_accuracy: 1.0000
# Epoch 33/100
# 2/2 [==============================] - 1s 594ms/step - loss: 0.3247 - accuracy: 0.8596 - val_loss: 0.1052 - val_accuracy: 1.0000
# Epoch 34/100
# 2/2 [==============================] - 1s 804ms/step - loss: 0.3461 - accuracy: 0.8246 - val_loss: 0.0803 - val_accuracy: 1.0000
# Epoch 35/100
# 2/2 [==============================] - 1s 724ms/step - loss: 0.2544 - accuracy: 0.9123 - val_loss: 0.0592 - val_accuracy: 1.0000
# Epoch 36/100
# 2/2 [==============================] - 1s 566ms/step - loss: 0.2696 - accuracy: 0.8947 - val_loss: 0.0627 - val_accuracy: 1.0000
# Epoch 37/100
# 2/2 [==============================] - 1s 775ms/step - loss: 0.2449 - accuracy: 0.9123 - val_loss: 0.0920 - val_accuracy: 1.0000
# Epoch 38/100
# 2/2 [==============================] - 1s 667ms/step - loss: 0.3865 - accuracy: 0.8246 - val_loss: 0.0733 - val_accuracy: 1.0000
# Epoch 39/100
# 2/2 [==============================] - 1s 737ms/step - loss: 0.2559 - accuracy: 0.9123 - val_loss: 0.0761 - val_accuracy: 1.0000
# Epoch 40/100
# 2/2 [==============================] - 1s 546ms/step - loss: 0.3670 - accuracy: 0.8070 - val_loss: 0.0831 - val_accuracy: 1.0000
# Epoch 41/100
# 2/2 [==============================] - 1s 678ms/step - loss: 0.3244 - accuracy: 0.9123 - val_loss: 0.1062 - val_accuracy: 0.9333
# Epoch 42/100
# 2/2 [==============================] - 1s 550ms/step - loss: 0.2543 - accuracy: 0.8772 - val_loss: 0.1338 - val_accuracy: 0.9333
# Epoch 43/100
# 2/2 [==============================] - 1s 687ms/step - loss: 0.3886 - accuracy: 0.8772 - val_loss: 0.1156 - val_accuracy: 0.9333
# Epoch 44/100
# 2/2 [==============================] - 1s 665ms/step - loss: 0.3256 - accuracy: 0.8596 - val_loss: 0.0871 - val_accuracy: 1.0000
# Epoch 45/100
# 2/2 [==============================] - 1s 703ms/step - loss: 0.3641 - accuracy: 0.8596 - val_loss: 0.0828 - val_accuracy: 1.0000
# Epoch 46/100
# 2/2 [==============================] - 1s 567ms/step - loss: 0.3573 - accuracy: 0.8421 - val_loss: 0.0988 - val_accuracy: 1.0000
# Epoch 47/100
# 2/2 [==============================] - 1s 707ms/step - loss: 0.2767 - accuracy: 0.8772 - val_loss: 0.1189 - val_accuracy: 1.0000
# Epoch 48/100
# 2/2 [==============================] - 1s 721ms/step - loss: 0.2453 - accuracy: 0.8421 - val_loss: 0.0998 - val_accuracy: 1.0000
# Epoch 49/100
# 2/2 [==============================] - 1s 660ms/step - loss: 0.1970 - accuracy: 0.9298 - val_loss: 0.0888 - val_accuracy: 1.0000
# Epoch 50/100
# 2/2 [==============================] - 1s 602ms/step - loss: 0.4221 - accuracy: 0.8070 - val_loss: 0.0912 - val_accuracy: 1.0000
# Epoch 51/100
# 2/2 [==============================] - 1s 637ms/step - loss: 0.2568 - accuracy: 0.8596 - val_loss: 0.1062 - val_accuracy: 1.0000
# Epoch 52/100
# 2/2 [==============================] - 1s 540ms/step - loss: 0.2991 - accuracy: 0.8596 - val_loss: 0.1288 - val_accuracy: 0.9333
# Epoch 53/100
# 2/2 [==============================] - 1s 540ms/step - loss: 0.3098 - accuracy: 0.8596 - val_loss: 0.1721 - val_accuracy: 0.9333
# Epoch 54/100
# 2/2 [==============================] - 1s 550ms/step - loss: 0.3800 - accuracy: 0.8772 - val_loss: 0.1311 - val_accuracy: 0.9333
# Epoch 55/100
# 2/2 [==============================] - 1s 650ms/step - loss: 0.2464 - accuracy: 0.8596 - val_loss: 0.1294 - val_accuracy: 0.9333
# Epoch 56/100
# 2/2 [==============================] - 1s 650ms/step - loss: 0.3802 - accuracy: 0.8246 - val_loss: 0.1522 - val_accuracy: 0.9333
# Epoch 57/100
# 2/2 [==============================] - 1s 522ms/step - loss: 0.2919 - accuracy: 0.8596 - val_loss: 0.1410 - val_accuracy: 0.9333
# Epoch 58/100
# 2/2 [==============================] - 1s 628ms/step - loss: 0.1901 - accuracy: 0.9474 - val_loss: 0.1660 - val_accuracy: 0.9333
# Epoch 59/100
# 2/2 [==============================] - 1s 634ms/step - loss: 0.2068 - accuracy: 0.9123 - val_loss: 0.1699 - val_accuracy: 0.9333
# Epoch 60/100
# 2/2 [==============================] - 1s 629ms/step - loss: 0.3774 - accuracy: 0.8246 - val_loss: 0.1127 - val_accuracy: 0.9333
# Epoch 61/100
# 2/2 [==============================] - 1s 533ms/step - loss: 0.2030 - accuracy: 0.9298 - val_loss: 0.0937 - val_accuracy: 1.0000
# Epoch 62/100
# 2/2 [==============================] - 1s 649ms/step - loss: 0.2550 - accuracy: 0.9123 - val_loss: 0.0870 - val_accuracy: 1.0000
# Epoch 63/100
# 2/2 [==============================] - 1s 640ms/step - loss: 0.2531 - accuracy: 0.8947 - val_loss: 0.0867 - val_accuracy: 1.0000
# Epoch 64/100
# 2/2 [==============================] - 1s 543ms/step - loss: 0.5382 - accuracy: 0.8246 - val_loss: 0.0841 - val_accuracy: 1.0000
# Epoch 65/100
# 2/2 [==============================] - 1s 703ms/step - loss: 0.3278 - accuracy: 0.8070 - val_loss: 0.1827 - val_accuracy: 0.9333
# Epoch 66/100
# 2/2 [==============================] - 1s 641ms/step - loss: 0.2928 - accuracy: 0.8246 - val_loss: 0.1123 - val_accuracy: 1.0000
# Epoch 67/100
# 2/2 [==============================] - 1s 633ms/step - loss: 0.3339 - accuracy: 0.8772 - val_loss: 0.0996 - val_accuracy: 1.0000
# Epoch 68/100
# 2/2 [==============================] - 1s 545ms/step - loss: 0.3030 - accuracy: 0.8596 - val_loss: 0.1587 - val_accuracy: 0.9333
# Epoch 69/100
# 2/2 [==============================] - 1s 635ms/step - loss: 0.2288 - accuracy: 0.9123 - val_loss: 0.1310 - val_accuracy: 0.9333
# Epoch 70/100
# 2/2 [==============================] - 1s 691ms/step - loss: 0.1986 - accuracy: 0.9474 - val_loss: 0.1085 - val_accuracy: 1.0000
# Epoch 71/100
# 2/2 [==============================] - 1s 671ms/step - loss: 0.3083 - accuracy: 0.8421 - val_loss: 0.1027 - val_accuracy: 1.0000
# Epoch 72/100
# 2/2 [==============================] - 1s 586ms/step - loss: 0.2450 - accuracy: 0.8596 - val_loss: 0.1323 - val_accuracy: 0.9333
# Epoch 73/100
# 2/2 [==============================] - 1s 548ms/step - loss: 0.2812 - accuracy: 0.8947 - val_loss: 0.2064 - val_accuracy: 0.8667
# Epoch 74/100
# 2/2 [==============================] - 1s 650ms/step - loss: 0.3159 - accuracy: 0.9123 - val_loss: 0.1523 - val_accuracy: 0.9333
# Epoch 75/100
# 2/2 [==============================] - 1s 526ms/step - loss: 0.3002 - accuracy: 0.8947 - val_loss: 0.0850 - val_accuracy: 1.0000
# Epoch 76/100
# 2/2 [==============================] - 1s 542ms/step - loss: 0.2463 - accuracy: 0.9123 - val_loss: 0.0842 - val_accuracy: 1.0000
# Epoch 77/100
# 2/2 [==============================] - 1s 557ms/step - loss: 0.3103 - accuracy: 0.8947 - val_loss: 0.0822 - val_accuracy: 1.0000
# Epoch 78/100
# 2/2 [==============================] - 1s 654ms/step - loss: 0.2506 - accuracy: 0.8947 - val_loss: 0.1870 - val_accuracy: 0.9333
# Epoch 79/100
# 2/2 [==============================] - 1s 600ms/step - loss: 0.4255 - accuracy: 0.8596 - val_loss: 0.1590 - val_accuracy: 0.9333
# Epoch 80/100
# 2/2 [==============================] - 1s 546ms/step - loss: 0.2979 - accuracy: 0.8596 - val_loss: 0.0687 - val_accuracy: 1.0000
# Epoch 81/100
# 2/2 [==============================] - 1s 681ms/step - loss: 0.3069 - accuracy: 0.8596 - val_loss: 0.0770 - val_accuracy: 1.0000
# Epoch 82/100
# 2/2 [==============================] - 1s 742ms/step - loss: 0.2693 - accuracy: 0.8772 - val_loss: 0.0653 - val_accuracy: 1.0000
# Epoch 83/100
# 2/2 [==============================] - 1s 651ms/step - loss: 0.2572 - accuracy: 0.9298 - val_loss: 0.0743 - val_accuracy: 1.0000
# Epoch 84/100
# 2/2 [==============================] - 1s 652ms/step - loss: 0.2264 - accuracy: 0.9649 - val_loss: 0.0711 - val_accuracy: 1.0000
# Epoch 85/100
# 2/2 [==============================] - 1s 652ms/step - loss: 0.2206 - accuracy: 0.8947 - val_loss: 0.0681 - val_accuracy: 1.0000
# Epoch 86/100
# 2/2 [==============================] - 1s 545ms/step - loss: 0.2136 - accuracy: 0.9123 - val_loss: 0.0785 - val_accuracy: 1.0000
# Epoch 87/100
# 2/2 [==============================] - 1s 540ms/step - loss: 0.2881 - accuracy: 0.8772 - val_loss: 0.0808 - val_accuracy: 1.0000
# Epoch 88/100
# 2/2 [==============================] - 1s 528ms/step - loss: 0.3465 - accuracy: 0.8947 - val_loss: 0.0777 - val_accuracy: 1.0000
# Epoch 89/100
# 2/2 [==============================] - 1s 592ms/step - loss: 0.2086 - accuracy: 0.9649 - val_loss: 0.1268 - val_accuracy: 1.0000
# Epoch 90/100
# 2/2 [==============================] - 1s 549ms/step - loss: 0.2254 - accuracy: 0.9298 - val_loss: 0.1832 - val_accuracy: 0.9333
# Epoch 91/100
# 2/2 [==============================] - 1s 565ms/step - loss: 0.3076 - accuracy: 0.8421 - val_loss: 0.1132 - val_accuracy: 1.0000
# Epoch 92/100
# 2/2 [==============================] - 1s 607ms/step - loss: 0.3477 - accuracy: 0.8246 - val_loss: 0.0943 - val_accuracy: 1.0000
# Epoch 93/100
# 2/2 [==============================] - 1s 564ms/step - loss: 0.2903 - accuracy: 0.8947 - val_loss: 0.0996 - val_accuracy: 1.0000
# Epoch 94/100
# 2/2 [==============================] - 1s 629ms/step - loss: 0.2503 - accuracy: 0.9123 - val_loss: 0.1011 - val_accuracy: 1.0000
# Epoch 95/100
# 2/2 [==============================] - 1s 534ms/step - loss: 0.2120 - accuracy: 0.9123 - val_loss: 0.1418 - val_accuracy: 1.0000
# Epoch 96/100
# 2/2 [==============================] - 1s 721ms/step - loss: 0.2370 - accuracy: 0.9123 - val_loss: 0.1240 - val_accuracy: 1.0000
# Epoch 97/100
# 2/2 [==============================] - 1s 616ms/step - loss: 0.1905 - accuracy: 0.9474 - val_loss: 0.1081 - val_accuracy: 1.0000
# Epoch 98/100
# 2/2 [==============================] - 1s 708ms/step - loss: 0.3007 - accuracy: 0.8772 - val_loss: 0.1289 - val_accuracy: 0.9333
# Epoch 99/100
# 2/2 [==============================] - 1s 655ms/step - loss: 0.3675 - accuracy: 0.8596 - val_loss: 0.1226 - val_accuracy: 1.0000
# Epoch 100/100
# 2/2 [==============================] - 1s 573ms/step - loss: 0.2724 - accuracy: 0.8947 - val_loss: 0.1466 - val_accuracy: 0.9333

# %%
# classification report of test dataset of spiral:
y_pred_sp3 = model7.predict(test_sp)
pred_sp = np.argmax(y_pred_sp3,axis=1)
ground_sp = np.argmax(tlables_sp,axis=1)
print(classification_report(ground_sp,pred_sp))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000140258E89D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 3s 3s/step
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81        15
#            1       0.85      0.73      0.79        15
#
#     accuracy                           0.80        30
#    macro avg       0.81      0.80      0.80        30
# weighted avg       0.81      0.80      0.80        30

# %%
# classification report of test dataset of wave:
y_pred_wa3 = model8.predict(test_wa)
pred_wa = np.argmax(y_pred_wa3,axis=1)
ground_wa = np.argmax(tlables_wa,axis=1)
print(classification_report(ground_wa,pred_wa))
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000140258E9000> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 3s 3s/step
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87        15
#            1       0.87      0.87      0.87        15
#
#     accuracy                           0.87        30
#    macro avg       0.87      0.87      0.87        30
# weighted avg       0.87      0.87      0.87        30

# %%
# plotting the accuracy and loss of spiral training and validation dataset:
get_acc7 = sp_7.history['accuracy']
value_acc7 = sp_7.history['val_accuracy']
get_loss7 = sp_7.history['loss']
validation_loss7 = sp_7.history['val_loss']

epochs7 = range(len(get_acc7))
plt.plot(epochs7, get_acc7, 'r',label='Accuracy of Training data')
plt.plot(epochs7, value_acc7, 'b',label='Accuracy of Validation data')
plt.title("Training vs validation accuracy - Spiral")
plt.legend(loc=0)
plt.figure()
plt.show()
epochs7 = range(len(get_loss7))
plt.plot(epochs7, get_loss7, 'r',label='Loss of Training data')
plt.plot(epochs7, validation_loss7, 'b',label='Loss of Validation data')
plt.title("Training vs validation loss - Spiral")
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
# plotting the accuracy and loss of wave training and validation dataset:
get_acc8 = wa_8.history['accuracy']
value_acc8 = wa_8.history['val_accuracy']
get_loss8 = wa_8.history['loss']
validation_loss8 = wa_8.history['val_loss']

epochs8 = range(len(get_acc8))
plt.plot(epochs8, get_acc8, 'r',label='Accuracy of Training data')
plt.plot(epochs8, value_acc8, 'b',label='Accuracy of Validation data')
plt.title("Training vs validation accuracy - Wave")
plt.legend(loc=0)
plt.figure()
plt.show()
epochs8 = range(len(get_loss8))
plt.plot(epochs8, get_loss8, 'r',label='Loss of Training data')
plt.plot(epochs8, validation_loss8, 'b',label='Loss of Validation data')
plt.title("Training vs validation loss - Wave")
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
# Threshold fuction:
def thresh_predict(arr,val=0.40):
    ans = []
    for i in arr[: , 1]:
        if( i>= val):
            ans.append(1)
        else:
            ans.append(0)
    ans = np.array(ans)
    return ans

# %% [markdown]
# ### Ensembling the model VGG16, MobileNetV2 and DenseNet201

# %%
# for spiral
pred_sp = (y_pred_sp1  + y_pred_sp2 + y_pred_sp3)/3
pred_sp = thresh_predict(pred_sp)
print(classification_report(ground_sp,pred_sp))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81        15
#            1       0.85      0.73      0.79        15
#
#     accuracy                           0.80        30
#    macro avg       0.81      0.80      0.80        30
# weighted avg       0.81      0.80      0.80        30

# %%
# for wave 
pred_wa = (y_pred_wa1  + y_pred_wa2 + y_pred_wa3)/3
pred_wa = thresh_predict(pred_wa)
print(classification_report(ground_wa,pred_wa))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90        15
#            1       0.93      0.87      0.90        15
#
#     accuracy                           0.90        30
#    macro avg       0.90      0.90      0.90        30
# weighted avg       0.90      0.90      0.90        30

# %% [markdown]
# ### Save the Models

# %%
# model3.save("VGG16_sp.h5")
# model4.save("VGG16_wa.h5")

# model5.save("MobileNetV2_sp.h5")
# model6.save("MobileNetV2_wa.h5")

# model7.save("DenseNet201_sp.h5")
# model8.save("DenseNet201_wa.h5")
